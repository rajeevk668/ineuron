# %% [markdown]
# # AssignmentIneoron 20

# %% [markdown]
# # 💡 Question-1
#
# Given a binary tree, your task is to find subtree with maximum sum in tree.
#
# Examples:
#
# Input1 :
#
#        1
#
#      /   \
#
#    2      3
#
#   / \    / \
#
# 4   5  6   7
#
# Output1 : 28
#
# As all the tree elements are positive, the largest subtree sum is equal to sum of all tree elements.
#
# Input2 :
#
#        1
#
#      /    \
#
#   -2      3
#
#   / \    /  \
#
# 4   5  -6   2
#
# Output2 : 7
#
# Subtree with largest sum is :
#
#  -2
#
#  / \
#
# 4   5
#
# Also, entire tree sum is also 7.
#
# </aside>

# %% [markdown]
# To find the subtree with the maximum sum in a binary tree, you can use a recursive approach. Here's the algorithm you can follow:
#
# Define a global variable maxSum and initialize it with a minimum value, such as negative infinity.
#
# Create a function called maxSubtreeSum that takes a binary tree node as input and returns the sum of the subtree rooted at that node.
#
# In the maxSubtreeSum function:
#
# If the input node is null, return 0.
# Recursively calculate the sum of the left subtree by calling maxSubtreeSum with the left child of the current node.
# Recursively calculate the sum of the right subtree by calling maxSubtreeSum with the right child of the current node.
# Calculate the sum of the current subtree by adding the values of the current node, the sum of the left subtree, and the sum of the right subtree.
# If the calculated sum is greater than the maxSum variable, update maxSum with the new maximum value.
# Return the sum of the current subtree.
# Call the maxSubtreeSum function with the root of the binary tree.
#
# The maximum sum of a subtree will be stored in the maxSum variable. Return maxSum as the result.

# %%
# Binary tree node definition
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def maxSubtreeSum(root):
    global maxSum
    if root is None:
        return 0
    
    leftSum = maxSubtreeSum(root.left)
    rightSum = maxSubtreeSum(root.right)
    
    subtreeSum = root.value + leftSum + rightSum
    
    maxSum = max(maxSum, subtreeSum)
    
    return subtreeSum

# Test the algorithm with the given examples
# Example 1
root1 = Node(1)
root1.left = Node(2)
root1.right = Node(3)
root1.left.left = Node(4)
root1.left.right = Node(5)
root1.right.left = Node(6)
root1.right.right = Node(7)

maxSum = float('-inf')
result1 = maxSubtreeSum(root1)
print("Output1:", result1)  # Output1: 28

# Example 2
root2 = Node(1)
root2.left = Node(-2)
root2.right = Node(3)
root2.left.left = Node(4)
root2.left.right = Node(5)
root2.right.left = Node(-6)
root2.right.right = Node(2)

maxSum = float('-inf')
result2 = maxSubtreeSum(root2)
print("Output2:", result2)  # Output2: 7
# Out:
# Output1: 28
# Output2: 7

# %% [markdown]
# In Example 1, the maximum sum is equal to the sum of all tree elements because all elements are positive.
#
# In Example 2, the subtree with the largest sum is the subtree rooted at the node with value -2, with a sum of 7.

# %% [markdown]
# # 💡 Question-2
#
# Construct the BST (Binary Search Tree) from its given level order traversal.
#
# Example:
#
# Input: arr[] = {7, 4, 12, 3, 6, 8, 1, 5, 10}
#
# Output: BST:
#
#             7
#
#          /    \
#
#        4     12
#
#      /  \     /
#
#     3   6  8
#
#    /    /     \
#
#  1    5      10
#
# </aside>

# %% [markdown]
# To construct a Binary Search Tree (BST) from its level order traversal, you can follow these steps:
#
# Create an empty root node and assign the first element of the level order traversal array to it.
# Initialize an empty queue.
# Enqueue the root node into the queue.
# Iterate through the level order traversal array starting from the second element:
# Dequeue a node from the queue.
# If the current element is less than the node's value, create a new left child node with the current element and enqueue it.
# If the current element is greater than the node's value, create a new right child node with the current element and enqueue it.
# Repeat step 4 until all elements in the level order traversal array have been processed.
# Return the root node of the constructed BST.
# Using the given level order traversal array {7, 4, 12, 3, 6, 8, 1, 5, 10}, let's construct the BST:
#
# Start with the root node: 7.
# Enqueue the root node: [7].
# Process the second element, 4:
# Dequeue the root node 7.
# 4 is less than 7, so create a left child node with a value of 4 and enqueue it.
# Process the third element, 12:
# Dequeue the left child node 4.
# 12 is greater than 4, so create a right child node with a value of 12 and enqueue it.
# Process the fourth element, 3:
# Dequeue the right child node 12.
# 3 is less than 12, so create a left child node with a value of 3 and enqueue it.
# Process the fifth element, 6:
# Dequeue the left child node 3.
# 6 is greater than 3, so create a right child node with a value of 6 and enqueue it.
# Process the sixth element, 8:
# Dequeue the right child node 6.
# 8 is greater than 6, so create a right child node with a value of 8 and enqueue it.
# Process the seventh element, 1:
# Dequeue the left child node 6.
# 1 is less than 6, so create a left child node with a value of 1 and enqueue it.
# Process the eighth element, 5:
# Dequeue the right child node 8.
# 5 is less than 8, so create a left child node with a value of 5 and enqueue it.
# Process the ninth element, 10:
# Dequeue the left child node 1.
# 10 is greater than 1, so create a right child node with a value of 10 and enqueue it.
# All elements have been processed.
# The BST has been constructed.
# The resulting BST:
#
#
#           7
#        /     \
#       4       12
#      / \     /
#     3   6   8
#    /   /   /
#   1   5   10
# Note: The level order traversal of a BST may not be unique, but the structure of the BST remains the same.
#
#
#
#
#
# Regenerate response

# %% [markdown]
#           7
#        /     \
#       4       12
#      / \     /
#     3   6   8
#    /   /   /
#   1   5   10

# %% [markdown]
# # 💡 Question-3
#
# Given an array of size n. The problem is to check whether the given array can represent the level order traversal of a Binary Search Tree or not.
#
# Examples:
#
# Input1 : arr[] = {7, 4, 12, 3, 6, 8, 1, 5, 10}
#
# Output1 : Yes
#
# For the given arr[], the Binary Search Tree is:
#
#             7
#
#          /    \
#
#        4     12
#
#      /  \     /
#
#     3   6  8
#
#    /    /     \
#
#  1    5      10
#
# Input2 : arr[] = {11, 6, 13, 5, 12, 10}
#
# Output2 : No
#
# The given arr[] does not represent the level order traversal of a BST.
#
# </aside>

# %% [markdown]
# To check whether a given array can represent the level order traversal of a Binary Search Tree (BST), we can follow these steps:
#
# Initialize two variables, i and n, where i is set to 0 and n is the size of the input array.
# Create an empty queue data structure.
# Create a variable root and assign the value of the first element in the array to it.
# Enqueue root into the queue.
# Increment i.
# Start a loop while i is less than n and the queue is not empty.
# Create a variable current and dequeue an element from the queue. This element represents the current node.
# Increment i.
# Check if there are elements remaining in the array.
# If i is less than n and the next element in the array is less than current, enqueue the next element as the left child of current.
# Increment i.
# If i is less than n and the next element in the array is greater than current, enqueue the next element as the right child of current.
# If the next element in the array violates the BST property (either less than current for the right subtree or greater than current for the left subtree), return "No."
# If the loop completes without returning "No," return "Yes" because the array represents the level order traversal of a BST.

# %%
def is_level_order_bst(arr):
    n = len(arr)
    if n == 0:
        return True

    min_value = float('-inf')
    max_value = float('inf')
    i = 0

    while i < n:
        if arr[i] < min_value or arr[i] > max_value:
            return False

        if i + 1 < n and arr[i + 1] < arr[i]:
            max_value = arr[i] - 1
        elif i + 1 < n:
            j = i + 1
            while j < n:
                if arr[j] < arr[i]:
                    return False
                j += 1
            min_value = arr[i] + 1

        i += 1

    return True

# Test case 1
arr1 = [7, 4, 12, 3, 6, 8, 1, 5, 10]
print(is_level_order_bst(arr1))  # Output: True

# Test case 2
arr2 = [11, 6, 13, 5, 12, 10]
print(is_level_order_bst(arr2))  # Output: False
# Out:
# False
# False
